# %% [markdown]
# <a href="https://colab.research.google.com/github/simulate111/Climatic_Data/blob/main/NOAA_Global_Forecast_System_(GFS)_Amazon_Web_Services_(AWS)_S3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install herbie-data
# You also need these for GFS GRIB2 data processing
# !pip install xarray cfgrib
# Out:
# Collecting herbie-data
#   Downloading herbie_data-2025.12.0-py3-none-any.whl.metadata (17 kB)
# Collecting cfgrib>=0.9.15 (from herbie-data)
#   Downloading cfgrib-0.9.15.1-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 4.2 MB/s eta 0:00:00
# Collecting eccodes>=2.37.0 (from herbie-data)
#   Downloading eccodes-2.44.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from herbie-data) (2.0.2)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.12/dist-packages (from herbie-data) (2.2.2)
# Requirement already satisfied: pyproj>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from herbie-data) (3.7.2)
# Requirement already satisfied: requests>=2.23.3 in /usr/local/lib/python3.12/dist-packages (from herbie-data) (2.32.4)
# Requirement already satisfied: toml>=0.10.2 in /usr/local/lib/python3.12/dist-packages (from herbie-data) (0.10.2)
# Requirement already satisfied: xarray>=2025.1.1 in /usr/local/lib/python3.12/dist-packages (from herbie-data) (2025.12.0)
# Requirement already satisfied: attrs>=19.2 in /usr/local/lib/python3.12/dist-packages (from cfgrib>=0.9.15->herbie-data) (25.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from cfgrib>=0.9.15->herbie-data) (8.3.1)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from eccodes>=2.37.0->herbie-data) (2.0.0)
# Collecting findlibs (from eccodes>=2.37.0->herbie-data)
#   Downloading findlibs-0.1.2-py3-none-any.whl.metadata (4.5 kB)
# Collecting eccodeslib (from eccodes>=2.37.0->herbie-data)
#   Downloading eccodeslib-2.44.1.8-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->herbie-data) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->herbie-data) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->herbie-data) (2025.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj>=3.7.0->herbie-data) (2025.11.12)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.3->herbie-data) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.3->herbie-data) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.3->herbie-data) (2.5.0)
# Requirement already satisfied: packaging>=24.1 in /usr/local/lib/python3.12/dist-packages (from xarray>=2025.1.1->herbie-data) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.1->herbie-data) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->eccodes>=2.37.0->herbie-data) (2.23)
# Collecting eckitlib==1.32.4.8 (from eccodeslib->eccodes>=2.37.0->herbie-data)
#   Downloading eckitlib-1.32.4.8-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting fckitlib==0.14.1.8 (from eccodeslib->eccodes>=2.37.0->herbie-data)
#   Downloading fckitlib-0.14.1.8-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.1 kB)
# Downloading herbie_data-2025.12.0-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 7.9 MB/s eta 0:00:00
# Downloading cfgrib-0.9.15.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 4.2 MB/s eta 0:00:00
# Downloading eccodes-2.44.0-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.5/83.5 kB 7.8 MB/s eta 0:00:00
# Downloading eccodeslib-2.44.1.8-cp312-cp312-manylinux_2_28_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 63.5 MB/s eta 0:00:00
# Downloading eckitlib-1.32.4.8-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (44.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 MB 15.1 MB/s eta 0:00:00
# Downloading fckitlib-0.14.1.8-cp312-cp312-manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 84.0 MB/s eta 0:00:00
# Downloading findlibs-0.1.2-py3-none-any.whl (10 kB)
# Installing collected packages: findlibs, eckitlib, fckitlib, eccodeslib, eccodes, cfgrib, herbie-data
# Successfully installed cfgrib-0.9.15.1 eccodes-2.44.0 eccodeslib-2.44.1.8 eckitlib-1.32.4.8 fckitlib-0.14.1.8 findlibs-0.1.2 herbie-data-2025.12.0
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (2025.12.0)
# Requirement already satisfied: cfgrib in /usr/local/lib/python3.12/dist-packages (0.9.15.1)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from xarray) (2.0.2)
# Requirement already satisfied: packaging>=24.1 in /usr/local/lib/python3.12/dist-packages (from xarray) (25.0)
# Requirement already satisfied: pandas>=2.2 in /usr/local/lib/python3.12/dist-packages (from xarray) (2.2.2)
# Requirement already satisfied: attrs>=19.2 in /usr/local/lib/python3.12/dist-packages (from cfgrib) (25.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from cfgrib) (8.3.1)
# Requirement already satisfied: eccodes>=0.9.8 in /usr/local/lib/python3.12/dist-packages (from cfgrib) (2.44.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from eccodes>=0.9.8->cfgrib) (2.0.0)
# Requirement already satisfied: findlibs in /usr/local/lib/python3.12/dist-packages (from eccodes>=0.9.8->cfgrib) (0.1.2)
# Requirement already satisfied: eccodeslib in /usr/local/lib/python3.12/dist-packages (from eccodes>=0.9.8->cfgrib) (2.44.1.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2->xarray) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->eccodes>=0.9.8->cfgrib) (2.23)
# Requirement already satisfied: eckitlib==1.32.4.8 in /usr/local/lib/python3.12/dist-packages (from eccodeslib->eccodes>=0.9.8->cfgrib) (1.32.4.8)
# Requirement already satisfied: fckitlib==0.14.1.8 in /usr/local/lib/python3.12/dist-packages (from eccodeslib->eccodes>=0.9.8->cfgrib) (0.14.1.8)

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)

# %%
import pandas as pd
import numpy as np
import xarray as xr
import warnings
import shutil
from herbie import Herbie
from datetime import datetime, timedelta
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm  # Progress bar library

# Silence the logs
warnings.filterwarnings("ignore")

cities = {
    "Turku": {"lat": 60.45, "lon": 22.26},
    "Copenhagen": {"lat": 55.67, "lon": 12.56},
    "Stockholm": {"lat": 59.32, "lon": 18.06},
    "Oslo": {"lat": 59.91, "lon": 10.75}
}

MAX_WORKERS = 30

def fetch_hour(timestamp_tuple):
    date_str, fxx = timestamp_tuple
    try:
        H = Herbie(date_str, model="gfs", product="pgrb2.0p25", fxx=fxx, verbose=False)
        search_str = ":TMP:2 m above ground|:UGRD:10 m above ground|:VGRD:10 m above ground|:DSWRF:surface"
        ds_list = H.xarray(search_str)

        ds = xr.merge(ds_list, compat='override') if isinstance(ds_list, list) else ds_list
        solar_var = 'sdswrf' if 'sdswrf' in ds.data_vars else 'dswrf'

        hour_results = []
        for name, coords in cities.items():
            lon_360 = coords['lon'] if coords['lon'] >= 0 else 360 + coords['lon']
            p = ds.sel(latitude=coords['lat'], longitude=lon_360, method="nearest")

            u, v = float(p['u10'].values), float(p['v10'].values)
            hour_results.append({
                "City": name,
                "Timestamp": p.valid_time.values,
                "GHI_Wm2": round(float(p[solar_var].values), 2),
                "Temp_C": round(float(p['t2m'].values) - 273.15, 2),
                "Wind_ms": round(np.sqrt(u**2 + v**2), 2)
            })

        # Cleanup temp files
        shutil.rmtree(H.get_local_path().parent, ignore_errors=True)
        return hour_results
    except Exception:
        return None

if __name__ == "__main__":
    tasks = []
    start_date = datetime(2024, 1, 1)
    for day in range(366):
        d_str = (start_date + timedelta(days=day)).strftime("%Y-%m-%d 00:00")
        for f in range(1, 25):
            tasks.append((d_str, f))

    print(f"🔥 Starting MAX SPEED extraction (30 workers)")

    # Wrap the executor in tqdm to monitor progress
    all_extracted_data = []
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        # We use list(tqdm(executor.map(...))) to trigger the bar
        results = list(tqdm(executor.map(fetch_hour, tasks), total=len(tasks), desc="Downloading 2024 GFS"))

    print("\n✅ Download complete. Flattening and saving files...")

    flat_results = [item for sublist in results if sublist for item in sublist]
    df_main = pd.DataFrame(flat_results)

    for name in cities:
        city_df = df_main[df_main['City'] == name].sort_values('Timestamp')
        city_df.to_csv(f"{name.lower()}_gfs_2024.csv", index=False)
        print(f"💾 Saved: {name.lower()}_gfs_2024.csv")
# Out:
# 🔥 Starting MAX SPEED extraction (30 workers)
# Downloading 2024 GFS:   2%|▏         | 194/8784 [01:30<1:02:58,  2.27it/s]
